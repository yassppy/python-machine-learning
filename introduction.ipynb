# %% [markdown]
# ## ¿Qué es Machine Learning?

# %% [markdown]
# El Machine Learning (Aprendizaje Automático) es una disciplina de la Inteligencia Artificial que permite a los sistemas aprender de la experiencia (los datos). Su objetivo es construir modelos que, actuando como un "niño digital" 👶 que aprende de patrones, puedan realizar predicciones, clasificaciones o tomar decisiones sobre información nueva de manera autónoma, es decir, sin ser programados explícitamente para cada tarea.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ¿Por que es necesario aprenderlo?

# %% [markdown]
# Aprenderlo es entender al mundo que está en constante automatización, desde plataformas u otras cosas con AI que usamos a diario y en base a cualquier área podemos transformar datos en valor estratégico.

# %% [markdown]
# ### Ejemplo

# %% [markdown]
# - Clasificación de correo electrónico: El algoritmo aprende si ese correo es deseado o se va al SPAM.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Sistema de recomendación de peliculas de Netflix: En base a las preferencias del usuario, lo que ha visto más veces, lo que le da a me gusta, lo que añade en la lista un conjunto de algoritmos van a realizar las recomendaciones.

# %% [markdown]
# ![image.png](attachment:image.png)
